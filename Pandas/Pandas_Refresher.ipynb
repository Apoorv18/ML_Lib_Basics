# %%
# Pandas Refresher
# Using Asus_Laptop_2020 Dataset from Kaggle 
# Link for reference - https://www.kaggle.com/bhageshcodebeast/asus-laptops-2020-jun
# Lets get started

# %%
# Regular imports
import pandas as pd
import matplotlib as plt

# Reading Dataset
laptop_sale=pd.read_csv("AsusLaptops.csv")
laptop_sale
# Out:
#     Unnamed: 0  Category       Series        ModelName  \
# 0            0   Premium   TUF Gaming   FX505DT-AL118T
# 1            1   Premium   TUF Gaming   FX705DT-AU092T
# 2            2   Premium   TUF Gaming   FX705DT-AU016T
# 3            3  Platinum  ROG-Strix G    G531GT-BQ002T
# 4            4  Platinum  ROG-Strix G    G531GT-AL264T
# ..         ...       ...          ...              ...
# 88          88   Premium      TUF A15  FA566IH-HN150TS
# 89          89   Premium      TUF A15   FA566II-HN230T
# 90          90   Premium      TUF A15   FA566II-HN231T
# 91          91   Premium      TUF A15   FA566IU-HN244T
# 92          92   Premium      TUF A15   FA566IU-HN246T
#
#                    Colour&Chassis  \
# 0                       GUN METAL
# 1                   BLACK PLASTIC
# 2                       GUN METAL
# 3                BLACK W+LIGHTBAR
# 4   1F-G Glacier Blue W+ Lightbar
# ..                            ...
# 88                  Fortress Gray
# ...

# %%
# Getting to know the data

laptop_sale.columns
# Out:
# Index(['Unnamed: 0', 'Category', 'Series', 'ModelName', 'Colour&Chassis',
#        'Description', 'Warrenty', 'MRP'],
#       dtype='object')

# %%
# Getting to know the data

laptop_sale.index
# Out:
# RangeIndex(start=0, stop=93, step=1)

# %%
# Getting to know the data
laptop_sale.dtypes
# Out:
# Unnamed: 0         int64
# Category          object
# Series            object
# ModelName         object
# Colour&Chassis    object
# Description       object
# Warrenty          object
# MRP                int64
# dtype: object

# %%
# Basic Viewing
laptop_sale.head(10)
# Out:
#    Unnamed: 0  Category       Series       ModelName  \
# 0           0   Premium   TUF Gaming  FX505DT-AL118T
# 1           1   Premium   TUF Gaming  FX705DT-AU092T
# 2           2   Premium   TUF Gaming  FX705DT-AU016T
# 3           3  Platinum  ROG-Strix G   G531GT-BQ002T
# 4           4  Platinum  ROG-Strix G   G531GT-AL264T
# 5           5   Premium   TUF Gaming  FX505DY-BQ024T
# 6           6   Premium   TUF Gaming  FX505GM-BQ344T
# 7           7   Premium   TUF Gaming  FX505GT-AL003T
# 8           8   Premium   TUF Gaming  FX505GT-AL007T
# 9           9   Premium   TUF Gaming  FX505GT-BQ006T
#
#                   Colour&Chassis  \
# 0                      GUN METAL
# 1                  BLACK PLASTIC
# 2                      GUN METAL
# 3               BLACK W+LIGHTBAR
# 4  1F-G Glacier Blue W+ Lightbar
# 5                  BLACK PLASTIC
# 6                       1C Black
# 7             2A-METAL TANK GREY
# 8                METAL TANK GREY
# 9                METAL TANK GREY
#
# ...

# %%
# Basic Viewing
laptop_sale.tail(10)
# Out:
#     Unnamed: 0 Category           Series        ModelName  \
# 83          83  Premium  VivoBook Gaming    F560UD-BQ237T
# 84          84  Premium  VivoBook Gaming    F560UD-BQ335T
# 85          85  Premium       TUF Gaming   FX505GD-BQ136T
# 86          86  Premium  VivoBook Gaming    F570ZD-DM226T
# 87          87  Premium          TUF A15   FA566IH-HN145T
# 88          88  Premium          TUF A15  FA566IH-HN150TS
# 89          89  Premium          TUF A15   FA566II-HN230T
# 90          90  Premium          TUF A15   FA566II-HN231T
# 91          91  Premium          TUF A15   FA566IU-HN244T
# 92          92  Premium          TUF A15   FA566IU-HN246T
#
#            Colour&Chassis                                        Description  \
# 83                  BLACK  15.6"FHD IPS+I5-8250U+8GB+1TB Firecuda+GTX1050...
# 84                  BLACK  i5-8250U +GTX 1050-4GB +8GB +1TB SSHD(FireCuda...
# 85  BLACK PATTERN PLASTIC  i5-8300H +GTX 1050-4GB +8GB +1TB HDD +15.6'+60...
# ...

# %%
# Statistical data
laptop_sale.describe()
# Out:
#        Unnamed: 0            MRP
# count   93.000000      93.000000
# mean    46.000000  154559.892473
# std     26.990739  109607.144111
# min      0.000000   64990.000000
# 25%     23.000000   88990.000000
# 50%     46.000000  110990.000000
# 75%     69.000000  185990.000000
# max     92.000000  649990.000000

# %%
# General info
laptop_sale.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 8 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0      93 non-null     int64
#  1   Category        93 non-null     object
#  2   Series          93 non-null     object
#  3   ModelName       93 non-null     object
#  4   Colour&Chassis  93 non-null     object
#  5   Description     93 non-null     object
#  6   Warrenty        93 non-null     object
#  7   MRP             93 non-null     int64
# dtypes: int64(2), object(6)
# memory usage: 5.9+ KB

# %%
# Creating new Datframe from existing one
df = laptop_sale.drop('Unnamed: 0',axis=1)
df
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP
# ...

# %%
# Some functions
min_mrp=df["MRP"].min()
max_mrp=df["MRP"].max()
mean_mpr=df["MRP"].mean()
sum_mrp=df["MRP"].sum()
min_mrp, max_mrp, mean_mpr, sum_mrp
# Out:
# (64990, 649990, 154559.8924731183, 14374070)

# %%
# Cross comparison 
pd.crosstab(df["Colour&Chassis"],df["Series"])
# Out:
# Series                                  ROG-G  ROG-Strix G  ROG-Strix Hero II  \
# Colour&Chassis
# 1A-GUN METAL                                0            0                  0
# 1A-SCAR Gunmetal                            0            0                  0
# 1B-BLACK PLASTIC                            0            0                  0
# 1C Black                                    0            0                  0
# 1F-G Glacier Blue W+ Lightbar               0            1                  0
# 2A-METAL TANK GREY                          0            0                  0
# Aluminum                                    1            0                  0
# Aluminum with plastic bone, Black with      0            0                  0
# BLACK                                       0            0                  0
# BLACK METAL                                 0            0                  0
# BLACK PATTERN PLASTIC                       0            0                  0
# ...

# %%
# Exporting without index
df.to_csv("Sale-Price-Edited.csv",index=False)

# %%
# loc & iloc
random_series=pd.Series(["Ironman","Thor","Black Widow", "Hulk", "Spiderman"])
random_series
# Out:
# 0        Ironman
# 1           Thor
# 2    Black Widow
# 3           Hulk
# 4      Spiderman
# dtype: object

# %%
random_series_1=pd.Series(["Ironman","Thor","Black Widow", "Hulk", "Spiderman"], index =[0,3,4,5,7])
random_series_1
# Out:
# 0        Ironman
# 3           Thor
# 4    Black Widow
# 5           Hulk
# 7      Spiderman
# dtype: object

# %%
# loc-index
# iloc-position
random_series_1.loc[3]
# Out:
# 'Thor'

# %%
# loc-index
# iloc-position
random_series_1.iloc[3]
# Out:
# 'Hulk'

# %%
# Dropping NaN data (None in this dataset)
df.dropna(inplace=True)
df
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP
# ...

# %%
# Appending a column
key_style=pd.Series(["Yes"])
df["Backlit"]=key_style

# %%
df
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP Backlit
# ...

# %%
# Filling NA value
df.fillna('Yes',inplace=True)
df
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP Backlit
# ...

# %%
df["Battery Backup"]=10
df
# Out:
#     Category       Series        ModelName                 Colour&Chassis  \
# 0    Premium   TUF Gaming   FX505DT-AL118T                      GUN METAL
# 1    Premium   TUF Gaming   FX705DT-AU092T                  BLACK PLASTIC
# 2    Premium   TUF Gaming   FX705DT-AU016T                      GUN METAL
# 3   Platinum  ROG-Strix G    G531GT-BQ002T               BLACK W+LIGHTBAR
# 4   Platinum  ROG-Strix G    G531GT-AL264T  1F-G Glacier Blue W+ Lightbar
# ..       ...          ...              ...                            ...
# 88   Premium      TUF A15  FA566IH-HN150TS                  Fortress Gray
# 89   Premium      TUF A15   FA566II-HN230T                  Fortress Gray
# 90   Premium      TUF A15   FA566II-HN231T                  Fortress Gray
# 91   Premium      TUF A15   FA566IU-HN244T                  Fortress Gray
# 92   Premium      TUF A15   FA566IU-HN246T                  Fortress Gray
#
#                                           Description Warrenty     MRP  \
# ...

# %%
# Shuffling
df_shuffled=df.sample(frac=1)
df_shuffled
# Out:
#     Category              Series        ModelName  \
# 1    Premium          TUF Gaming   FX705DT-AU092T
# 28  Platinum      ROG-Zephyrus S  GX701GXR-H6086T
# 30  Platinum               ROG-G    G703GI-E5148T
# 4   Platinum         ROG-Strix G    G531GT-AL264T
# 76   Premium          TUF Gaming   FX505GM-BQ415T
# ..       ...                 ...              ...
# 11        NO         ROG-Strix G    G531GT-AL017T
# 38  Platinum  ROG-Strix Scar III    G531GW-AZ113T
# 42  Platinum  ROG-Strix Scar III    G531GW-AZ014T
# 73   Premium          TUF Gaming   FX504GE-E4366T
# 70  Platinum      ROG-Zephyrus S  GX531GWR-ES024T
#
#                             Colour&Chassis  \
# 1                            BLACK PLASTIC
# 28                             BLACK METAL
# 30                                TITANIUM
# 4            1F-G Glacier Blue W+ Lightbar
# 76                            1A-GUN METAL
# ..                                     ...
# 11                        BLACK W+LIGHTBAR
# ...

# %%
## Applying lambda
df_1=pd.DataFrame()
df_1['MRP']=df["MRP"].apply(lambda x:x/100)
df_1
# Out:
#        MRP
# 0    779.9
# 1    809.9
# 2    949.9
# 3    979.9
# 4    989.9
# ..     ...
# 88   969.9
# 89   989.9
# 90  1109.9
# 91  1209.9
# 92  1289.9
#
# [93 rows x 1 columns]
